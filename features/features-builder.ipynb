# %%
# %pylab inline
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
from pyCBT.providers.gdrive.account import get_client
from pyCBT.providers.gdrive.historical import DriveTables

# %%
drive_client = get_client()
# Out:
# Your browser has been opened to visit:
# ()
#     https://accounts.google.com/o/oauth2/auth?scope=https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdrive&redirect_uri=http%3A%2F%2Flocalhost%3A8080%2F&response_type=code&client_id=693473631117-r01f6cl8lenbrrvpr2k2ouvh1qnpq49t.apps.googleusercontent.com&access_type=offline
# ()
# Authentication successful.

# %%
fxchoice_tables = DriveTables(reference="BTCUSD", client=drive_client, drive_data_id="1ZGXLOEApo1QxOFAoXOK63i0pKdJ4QcbE")

# %%
X = fxchoice_tables.get_joint_dataframe()

# %%
X.plot(subplots=True, figsize=(15,4*X.columns.size))
# Out:
# array([<matplotlib.axes._subplots.AxesSubplot object at 0x7f0eeea47790>,
# ...
#       dtype=object)

# %%
fxchoice_tables.get_technical()
# Out:
# Category     Technical                                                         \
# Name                %R         CCI          EMA        MA      MOM        ROC
# Date
# 2012-02-06 -100.000000 -124.316940     5.814000     5.814    -0.41  -6.721311
# 2012-02-07  -52.941176  -19.125683     5.772667     5.732    -0.41  -6.721311
# 2012-02-08  -64.285714  -37.037037     5.715111     5.660    -0.36  -6.040268
# 2012-02-09   -0.000000  116.797900     5.753407     5.652    -0.04  -0.681431
# 2012-02-10   -0.000000  102.490421     5.805605     5.696     0.22   3.866432
# 2012-02-11 -100.000000  -72.916667     5.737070     5.726     0.15   2.752294
# 2012-02-12 -100.000000  -83.333333     5.661380     5.690    -0.18  -3.163445
# 2012-02-13 -100.000000 -121.639785     5.527587     5.622    -0.34  -6.071429
# 2012-02-14 -100.000000 -151.639344     5.171724     5.348    -1.37 -23.499142
# 2012-02-15 -100.000000  -91.836735     4.891150     5.032    -1.58 -26.734349
# ...
