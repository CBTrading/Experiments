# %%
# %pylab inline
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
from pyCBT.providers.gdrive.account import get_client
from pyCBT.providers.gdrive.historical import DriveTables

from pyCBT.common._constants import features_params

# %%
drive_client = get_client()
# Out:
# Your browser has been opened to visit:
# ()
#     https://accounts.google.com/o/oauth2/auth?scope=https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdrive&redirect_uri=http%3A%2F%2Flocalhost%3A8080%2F&response_type=code&client_id=693473631117-r01f6cl8lenbrrvpr2k2ouvh1qnpq49t.apps.googleusercontent.com&access_type=offline
# ()
# Authentication successful.

# %%
sp500_tables = DriveTables(symbols=features_params, reference="S&P 500", client=drive_client)

# %%
X = sp500_tables.get_features()

# %%
X["Economic calendar"].plot(subplots=True, figsize=(15,10))
# Out:
# array([<matplotlib.axes._subplots.AxesSubplot object at 0x7f5bc8fea650>,
#        <matplotlib.axes._subplots.AxesSubplot object at 0x7f5bc8732290>,
#        <matplotlib.axes._subplots.AxesSubplot object at 0x7f5bc86f6610>,
#        <matplotlib.axes._subplots.AxesSubplot object at 0x7f5bc870c950>,
#        <matplotlib.axes._subplots.AxesSubplot object at 0x7f5bc868c210>,
#        <matplotlib.axes._subplots.AxesSubplot object at 0x7f5bc8646190>,
#        <matplotlib.axes._subplots.AxesSubplot object at 0x7f5bc85e5b10>,
#        <matplotlib.axes._subplots.AxesSubplot object at 0x7f5bc85d63d0>,
#        <matplotlib.axes._subplots.AxesSubplot object at 0x7f5bc8597b10>],
#       dtype=object)
