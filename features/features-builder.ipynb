# %%
# %pylab inline
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
from pyCBT.providers.gdrive.account import get_client
from pyCBT.providers.gdrive.historical import DriveTables

from pyCBT.common._constants import features_params

# %%
drive_client = get_client()
# Out:
# Your browser has been opened to visit:
# ()
#     https://accounts.google.com/o/oauth2/auth?scope=https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdrive&redirect_uri=http%3A%2F%2Flocalhost%3A8080%2F&response_type=code&client_id=693473631117-r01f6cl8lenbrrvpr2k2ouvh1qnpq49t.apps.googleusercontent.com&access_type=offline
# ()
# Authentication successful.

# %%
sp500_tables = DriveTables(symbols=features_params, reference="S&P 500", client=drive_client)

# %%
X = sp500_tables.get_joint_dataframe()

# %%
X["Economic calendar"].plot(subplots=True, figsize=(15,10))
# Out:
# array([<matplotlib.axes._subplots.AxesSubplot object at 0x7ff3fbf78b50>,
# ...
#       dtype=object)

# %%
sp500_tables.get_
# Out:
# Category     Indices                                                    \
# Name         S&P 500       DAX       DJA       DJI       DXY      FCHI
# Date
# 2006-01-04       NaN       NaN       NaN       NaN       NaN       NaN
# 2006-01-05  0.000016 -0.001284  0.000000  0.000000  0.002131 -0.000709
# 2006-01-06  0.009399  0.003587  0.000000  0.000000 -0.005373  0.006631
# 2006-01-09  0.003656  0.000143  0.000000  0.000000  0.004502  0.001631
# 2006-01-10 -0.000357 -0.007657  0.000000  0.000000  0.000896 -0.002699
# 2006-01-11  0.003481  0.006949  0.000000  0.000000 -0.003806  0.005874
# 2006-01-12 -0.006274  0.001670  0.000000  0.000000  0.005057 -0.000051
# 2006-01-13  0.001205 -0.010653  0.000000  0.000000 -0.006149 -0.008120
# 2006-01-17 -0.003557 -0.004182  0.000000  0.000000  0.004612 -0.008945
# 2006-01-18 -0.003975 -0.011822  0.000000  0.000000 -0.000448 -0.007291
# 2006-01-19  0.005564  0.006529  0.000000  0.000000  0.001456  0.008801
# ...
